# %% [markdown]
# ## Preprocess data

# %%
import pandas as pd
import json

top_relations = ['www.freebase.com/music/genre/albums',
                'www.freebase.com/time/event/locations',
                'www.freebase.com/location/location/time_zones']

rel_mappings = {'www.freebase.com/music/genre/albums' : ['http://dbpedia.org/ontology/genre'],
                'www.freebase.com/time/event/locations' : ['http://dbpedia.org/ontology/place'],
                'www.freebase.com/location/location/time_zones': ['http://dbpedia.org/ontology/timeZone',
                                                                 "http://dbpedia.org/property/timezone"]}

# %%
train = pd.read_csv("../data/SimpleQuestions/annotated_fb_data_train.txt", sep='\t', header=None)
test = pd.read_csv("../data/SimpleQuestions/annotated_fb_data_test.txt", sep='\t', header=None)
val = pd.read_csv("../data/SimpleQuestions/annotated_fb_data_valid.txt", sep='\t', header=None)

# %%
train = train[train[1].isin(top_relations)]
test = test[test[1].isin(top_relations)]
val = val[val[1].isin(top_relations)]

print(train.shape, test.shape, val.shape)
# Out:
# (1256, 4) (376, 4) (182, 4)

# %% [markdown]
# ## Train a classifier

# %%
import nltk

nltk.download('wordnet')
nltk.download('stopwords')

from nltk.tokenize import RegexpTokenizer
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer

tokenizer = RegexpTokenizer(r'\w+')
lemmatizer = WordNetLemmatizer()
stopwords = stopwords.words('english')
# Out:
# [nltk_data] Downloading package wordnet to /home/alex/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package stopwords to /home/alex/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
def preprocess_text(text, remove_stopwords=False):
    # clean_ascii
    tmp = "".join(i for i in text if ord(i) < 128)
    #lowercase
    tmp = tmp.lower()
    #normal form
    tokens = tokenizer.tokenize(tmp)
    #stopwords
    if remove_stopwords:
        prep_text = ' '.join(t for t in tokens if t not in stopwords)
    else:
        prep_text = ' '.join(t for t in tokens)
    
    return prep_text

# %%
# %%time

train['clean text'] = train[3].apply(lambda x: preprocess_text(x))
test['clean text'] = test[3].apply(lambda x: preprocess_text(x))
val['clean text'] = val[3].apply(lambda x: preprocess_text(x))
# Out:
# CPU times: user 203 ms, sys: 85 µs, total: 203 ms
# Wall time: 201 ms

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import classification_report

seed = 42

# %%
vectorizer = TfidfVectorizer(min_df=3,ngram_range=(1,1))
vectorizer.fit(train.append(test).append(val)['clean text'])
# Out:
# TfidfVectorizer(analyzer='word', binary=False, decode_error='strict',
#         dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#         lowercase=True, max_df=1.0, max_features=None, min_df=3,
#         ngram_range=(1, 1), norm='l2', preprocessor=None, smooth_idf=True,
#         stop_words=None, strip_accents=None, sublinear_tf=False,
#         token_pattern='(?u)\\b\\w\\w+\\b', tokenizer=None, use_idf=True,
#         vocabulary=None)

# %%
encoder = LabelEncoder()
encoder.fit(train.append(test).append(val)[1])
# Out:
# LabelEncoder()

# %%
print("Total number of unique words in data = {0}".format(len(list(vectorizer.vocabulary_.keys()))))
# Out:
# Total number of unique words in data = 261

# %%
X_train = vectorizer.transform(train['clean text'])
y_train = encoder.transform(train[1])

# %%
classifier = LogisticRegression(random_state=seed).fit(X_train, y_train)

# %%
X_test = vectorizer.transform(test['clean text'])
y_test = encoder.transform(test[1])

# %%
y_pred = classifier.predict(X_test)

# %%
print(classification_report(y_test, y_pred,target_names = encoder.inverse_transform([0, 1, 2,])))
# Out:
#                                                precision    recall  f1-score   support
#
# www.freebase.com/location/location/time_zones       0.99      1.00      1.00       117
#           www.freebase.com/music/genre/albums       0.99      1.00      1.00       221
#         www.freebase.com/time/event/locations       1.00      0.92      0.96        38
#
#                                   avg / total       0.99      0.99      0.99       376
# /home/alex/miniconda3/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:

# %%
# 74320  www.freebase.com/m/01kq6kh
# 74333  www.freebase.com/m/01h5txy
# 74468  www.freebase.com/m/02vlzl6
# 74479     www.freebase.com/m/0pg0
# 74528   www.freebase.com/m/02_37z
# 74543  www.freebase.com/m/01qd9d4
# 74675  www.freebase.com/m/04gvpmx
# 74681   www.freebase.com/m/03fz0m
# 74805  www.freebase.com/m/0wkd05g
# 74848   www.freebase.com/m/02fqwt
# 74994  www.freebase.com/m/01m8dsx
# 75023   www.freebase.com/m/02llzg
# 75154  www.freebase.com/m/01kd9dq
# 75230    www.freebase.com/m/0g8bw
# 75260   www.freebase.com/m/0bbzdt
# 75392  www.freebase.com/m/03c5jhv
# 75435  www.freebase.com/m/02vlzl6
# 75546  www.freebase.com/m/076yh3l
# 75614   www.freebase.com/m/02llzg
# 75634  www.freebase.com/m/03g67zm
# 75658    www.freebase.com/m/01js1
# 75737  www.freebase.com/m/049vj0b
# 75758   www.freebase.com/m/02llzg
# 75779  www.freebase.com/m/01hkns1
# 75787    www.freebase.com/m/05g2v
# 75815  www.freebase.com/m/05q57kl
# 75836  www.freebase.com/m/0f1chc0
# 75842  www.freebase.com/m/01r847m
# 75879  www.freebase.com/m/02z8m8s
#
#                                                        3  \
# 96                       what time zone is marrakech in?
# 164                           what album has folk music?
# 301        What's an example of a psychedelic rock album
# 311                  What is an example of a funk album?
# 454        What time zone does the chebanse township use
# 567                   what is an alternative rock album?
# 601                What's a country album by johnny cash
# 648        what's a jazz fusion by pierre moerlen's gong
# 651                 which time zone is guinea-bissau in?
# 674                    What is the name of a blues album
# 677            what is the time zone of odalengo grande?
# 706                       what what dream pop painted on
# 827          Where did the bombing of darwin take place?
# 922    which rock music albums were released by bambo...
# 924       what time zone includes hudson falls, new york
# 989          what is the time zone of pulteney, new york
# 1043   Which time zone is acquanegra sul chiese locat...
# 1127      what was Suzi Quatro's sixth rock music album?
# 1226                         what is an indie rock album
# 1278                what is a type of electronica music?
# 1340        What is the name of a psychedelic rock album
# 1379                       which time zone is sharon in
# 1383              what are examples of rock music albums
# 1487           which time zone was used in united states
# 1585           Which timezone is birch creek located in?
# 1697                               what album is country
# 1726             what album is a type of pop rock music?
# 1836                   What is a rock music album title?
# 1889                       what is a type of jazz album?
# 1987          where is the obama–mccain debates located?
# ...                                                  ...
# 74250  in what time zone is los trujillos-gabaldon lo...
# 74320                      Name a progressive rock album
# 74333           what is an album in the rock music genre
# 74468                                 Name a rock album.
# 74479   where took place the japanese occupation of attu
# 74528                 which time zone is sanilac county
# 74543                   What is an album of death metal?
# 74675                       what album plays indie rock?
# 74681               where did wrestlemania ix take place
# 74805              What is the name of a pop music album
# 74848                    which time zone is the emmet in
# 74994                      Name a progressive rock album
# 75023                       what time zone is brunate in
# 75154                                 what a funk album?
# 75230  what is the location of operations malheur i a...
# 75260                        what are gangsta rap albums
# 75392                which album is a  heavy metal album
# 75435             what album is under the genre screamo?
# 75546          What's an example of an electronica album
# 75614           what time zone is roccantica located in?
# 75634                What is the name of a dubstep album
# 75658                  where was the battle of chinsurah
# 75737                           Name a rock music album
# 75758                 what time zone is montelabbate in
# 75779         What is an example of a gangsta rap album?
# 75787        where did the arab–israeli conflict happen?
# 75815                what is an experimental music album
# 75836                       what is a jazz fusion album
# 75842                         what is a pop music album?
# 75879   What is the name of the dance music genre album?
#
#                                               clean text
# 96                        what time zone is marrakech in
# 164                            what album has folk music
# 301        what s an example of a psychedelic rock album
# 311                   what is an example of a funk album
# 454        what time zone does the chebanse township use
# 567                    what is an alternative rock album
# 601                what s a country album by johnny cash
# 648        what s a jazz fusion by pierre moerlen s gong
# 651                  which time zone is guinea bissau in
# 674                    what is the name of a blues album
# 677             what is the time zone of odalengo grande
# 706                       what what dream pop painted on
# 827           where did the bombing of darwin take place
# 922    which rock music albums were released by bambo...
# 924        what time zone includes hudson falls new york
# 989           what is the time zone of pulteney new york
# 1043   which time zone is acquanegra sul chiese locat...
# 1127       what was suzi quatro s sixth rock music album
# 1226                         what is an indie rock album
# 1278                 what is a type of electronica music
# 1340        what is the name of a psychedelic rock album
# 1379                        which time zone is sharon in
# 1383              what are examples of rock music albums
# 1487           which time zone was used in united states
# 1585            which timezone is birch creek located in
# 1697                               what album is country
# 1726              what album is a type of pop rock music
# 1836                    what is a rock music album title
# 1889                        what is a type of jazz album
# 1987            where is the obamamccain debates located
# ...                                                  ...
# 74250  in what time zone is los trujillos gabaldon lo...
# 74320                      name a progressive rock album
# 74333           what is an album in the rock music genre
# 74468                                  name a rock album
# 74479   where took place the japanese occupation of attu
# 74528                  which time zone is sanilac county
# 74543                    what is an album of death metal
# 74675                        what album plays indie rock
# 74681               where did wrestlemania ix take place
# 74805              what is the name of a pop music album
# 74848                    which time zone is the emmet in
# 74994                      name a progressive rock album
# 75023                       what time zone is brunate in
# 75154                                  what a funk album
# 75230  what is the location of operations malheur i a...
# 75260                        what are gangsta rap albums
# 75392                 which album is a heavy metal album
# 75435              what album is under the genre screamo
# 75546          what s an example of an electronica album
# 75614            what time zone is roccantica located in
# 75634                what is the name of a dubstep album
# 75658                  where was the battle of chinsurah
# 75737                            name a rock music album
# 75758                  what time zone is montelabbate in
# 75779          what is an example of a gangsta rap album
# 75787          where did the arabisraeli conflict happen
# 75815                what is an experimental music album
# 75836                        what is a jazz fusion album
# 75842                          what is a pop music album
# 75879    what is the name of the dance music genre album
#
# [1256 rows x 5 columns]

# %%
text = preprocess_text("what can i see in berlin?")
vector = vectorizer.transform([text])
prediction = classifier.predict(vector)
class_ = encoder.inverse_transform(prediction)

predicate = rel_mappings[class_[0]][0]
print(predicate)
# Out:
# http://dbpedia.org/ontology/genre
# /home/alex/miniconda3/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:

# %%
import requests

response = requests.get(url="https://api.dbpedia-spotlight.org/en/annotate",
                            params={"text": preprocess_text(text, True), "confidence": "0.3"},
                            headers={'accept': 'application/json'}).json()

# %%
response['Resources']
# Out:
# [{'@URI': 'http://dbpedia.org/resource/List_of_WWE_pay-per-view_events',
#   '@support': '3709',
#   '@types': '',
#   '@surfaceForm': 'event',
#   '@offset': '0',
#   '@similarityScore': '0.6635543720903484',
#   '@percentageOfSecondRank': '0.30828768305323'},
#  {'@URI': 'http://dbpedia.org/resource/Italy',
#   '@support': '150965',
#   '@types': 'Wikidata:Q6256,Schema:Place,Schema:Country,DBpedia:PopulatedPlace,DBpedia:Place,DBpedia:Location,DBpedia:Country',
#   '@surfaceForm': 'italia',
#   '@offset': '17',
#   '@similarityScore': '0.9999997860977687',
#   '@percentageOfSecondRank': '0.0'},
#  {'@URI': 'http://dbpedia.org/resource/Roman_Empire',
#   '@support': '30520',
#   '@types': 'Wikidata:Q6256,Schema:Place,Schema:Country,DBpedia:PopulatedPlace,DBpedia:Place,DBpedia:Location,DBpedia:Country',
#   '@surfaceForm': 'roman empire',
#   '@offset': '24',
#   '@similarityScore': '0.9990581887699139',
#   '@percentageOfSecondRank': '4.644933348495679E-4'}]

# %%
subject = [uri['@URI'] for uri in response['Resources'] if len(uri['@types']) > 0][0]
print(subject)
# Out:
# http://dbpedia.org/resource/Italy

# %%
sparql = """
    PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
    PREFIX dbo: <http://dbpedia.org/ontology/>

    SELECT ?a
    WHERE
    { 
      OPTIONAL
      {
       # ?a <%s> <%s> .
      }
    }
""" % (predicate, subject)

# %%
sparql
# Out:
# '\n    PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>\n    PREFIX dbo: <http://dbpedia.org/ontology/>\n\n    SELECT ?a\n    WHERE\n    { \n      OPTIONAL\n      {\n       ?a <http://dbpedia.org/ontology/place> <http://dbpedia.org/resource/Italy> .\n      }\n    }\n'

# %%
response = requests.post(url="http://dbpedia.org/sparql",
                            params={"query": sparql},
                            headers={'accept': 'application/sparql-results+json'}).json()

# %%
response
# Out:
# {'head': {'link': [], 'vars': ['a']},
#  'results': {'distinct': False,
#   'ordered': True,
#   'bindings': [{'a': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/War_of_the_Polish_Succession'}},
#    {'a': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Gothic_War_(535–554)'}},
#    {'a': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Siege_of_Gaeta_(1815)'}},
#    {'a': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Battle_of_Placentia_(194_BC)'}},
#    {'a': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Siege_of_Mirandola_(1551)'}},
#    {'a': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Battle_of_Borghetto'}},
#    {'a': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Battle_of_Magnano'}},
#    {'a': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Battle_of_Tornavento'}},
#    {'a': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Battle_of_Carpi_(1815)'}},
#    {'a': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Battle_of_Casaglia'}},
#    {'a': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Battle_of_Castel_di_Sangro'}},
#    {'a': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Battle_of_Cesenatico'}},
#    {'a': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Battle_of_Pesaro'}},
#    {'a': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Battle_of_Ronco'}},
#    {'a': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Battle_of_Montichiari'}},
#    {'a': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Battle_of_Seminara_(1503)'}},
#    {'a': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Invasion_of_Elba'}},
#    {'a': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Battle_of_Anghiari'}},
#    {'a': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/War_of_the_Third_Coalition'}},
#    {'a': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Battle_of_Gemmano'}},
#    {'a': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Battle_of_Bologna'}},
#    {'a': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Battle_of_Cascina'}},
#    {'a': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Montenotte_Campaign'}},
#    {'a': {'type': 'uri',
#      'value': "http://dbpedia.org/resource/Sulla's_civil_wars"}},
#    {'a': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Anglo-Dutch_Wars'}},
#    {'a': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/First_Anglo-Dutch_War'}},
#    {'a': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Battle_of_Asculum'}},
#    {'a': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Battle_of_Campaldino'}},
#    {'a': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Battle_of_Cassano_(1799)'}},
#    {'a': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Battle_of_San_Romano'}},
#    {'a': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Battle_of_Ticinus'}},
#    {'a': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Battle_of_Tolentino'}},
#    {'a': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Battle_of_the_Himera_River_(311_BC)'}},
#    {'a': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Second_Battle_of_the_Piave_River'}},
#    {'a': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Battle_of_Garigliano'}},
#    {'a': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Battle_of_Modena_(1799)'}},
#    {'a': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Battle_of_San_Pietro'}},
#    {'a': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Battle_of_Landriano'}},
#    {'a': {'type': 'uri',
#      'value': "http://dbpedia.org/resource/Battle_of_Colle_Val_d'Elsa"}},
#    {'a': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Battle_of_Castagnaro'}},
#    {'a': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Battle_of_Caravaggio'}},
#    {'a': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/War_of_Urbino'}},
#    {'a': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Battle_of_Bassano'}},
#    {'a': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Franco-Spanish_War_(1635–59)'}},
#    {'a': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Siege_of_Syracuse_(278_BC)'}},
#    {'a': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Siege_of_Syracuse_(311–309_BC)'}},
#    {'a': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Siege_of_Syracuse_(343_BC)'}},
#    {'a': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Siege_of_Syracuse_(397_BC)'}},
#    {'a': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Siege_of_Genoa_(1747)'}},
#    {'a': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Battle_of_Piave_River_(1809)'}},
#    {'a': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Siege_of_Florence_(405)'}},
#    {'a': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Adriatic_Campaign_of_World_War_II'}},
#    {'a': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Siege_of_Mantua_(1796–97)'}},
#    {'a': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Siege_of_Mantua_(1799)'}},
#    {'a': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Battle_of_Mons_Lactarius'}},
#    {'a': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Battle_of_La_Motta_(1513)'}},
#    {'a': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Battle_of_Mentana'}},
#    {'a': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Po_Valley_raid'}},
#    {'a': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Spring_1945_offensive_in_Italy'}},
#    {'a': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Years_of_Lead_(Italy)'}},
#    {'a': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Battle_of_Montemurlo'}},
#    {'a': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Battle_of_Saticula'}},
#    {'a': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Siege_of_Asti_(402)'}},
#    {'a': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Operation_Maple_(Italy)'}},
#    {'a': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Battle_of_Monte_Cassino'}},
#    {'a': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Battle_of_Campo_Santo'}},
#    {'a': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Battle_of_Lake_Vadimo_(283_BC)'}},
#    {'a': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Battle_of_Lake_Vadimo_(310_BC)'}},
#    {'a': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Battle_of_Marciano'}},
#    {'a': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Battle_of_Verona_(1799)'}},
#    {'a': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Battle_of_Verona_(1805)'}},
#    {'a': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Battle_of_